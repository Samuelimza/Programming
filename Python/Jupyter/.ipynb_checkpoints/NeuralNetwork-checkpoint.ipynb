# %%
import time
import random
import numpy as np
import matplotlib.pyplot as plt
from skimage import io

# %%
# Created by Osama Ashhad Azmi in March '18

"""
To Do:
# Use np functions to append bias, delete delta
# (DONE) Fix the accuracy function for one hot compatibility
# Implement the cost function
# Use np.argmax at MARKER
# If possible clean the train function
"""

class NeuralNetwork:

    def __init__(self, layerN):
        self.m = None
        self.layerN = layerN
        self.w = [2 * np.random.random((layerN[i] + 1, layerN[i + 1])) - 1 for i in range(len(layerN) - 1)]
        self.layer = [None for _ in range(len(layerN))]

    # function to implement forward propagation
    def feedForward(self, X):
        self.layer[0] = self.addBias(X)
        for i in range(1, len(self.layerN) - 1):
            self.layer[i] = self.addBias(self.activate(self.layer[i - 1].dot(self.w[i - 1])))
        self.layer[len(self.layerN) - 1] = self.activate(self.layer[len(self.layerN) - 2].dot(self.w[len(self.layerN) - 2]))

    # function to implement back propagation
    def backProp(self, Y):
        delta = [None for _ in range(len(self.layerN))]
        delta[len(self.layerN) - 1] = Y - self.layer[len(self.layerN) - 1]
        for i in range(len(self.layerN) - 2, 0, -1):
            delta[i] = self.removeRedundantDelta((delta[i + 1].dot(self.w[i].T)) * self.activate(self.layer[i], True))
        for i in range(len(self.layerN) - 1):
            self.w[i] += self.layer[i].T.dot(delta[i + 1]) * (1 / len(Y))

    # function to train the NN on passed data
    def train(self, X, Y, epochs, batchSize=None):
        self.m = len(X)
        if batchSize is None:
            flag = False
        else:
            indices = [i for i in range(self.m)]
            random.shuffle(indices)
            temp = [X[i] for i in indices]
            X = temp
            temp = [Y[i] for i in indices]
            Y = temp
            flag = True

        for j in range(epochs):
            # print('Epoch:', j)
            if flag:
                i = 0
                while i + batchSize < self.m:
                    self.feedForward(X[i:i + batchSize])
                    self.backProp(Y[i:i + batchSize])
                    i += batchSize
                self.feedForward(X[i:self.m])
                self.backProp(Y[i:self.m])
            else:
                self.feedForward(X)
                self.backProp(Y)

    # function to calculate accuracy on passed data
    def getAccuracy(self, X, Y):
        self.feedForward(X)
        output = self.layer[len(self.layerN) - 1]
        count = 0
        for i in range(len(output)):
            maxi = 0
            maxIndex = None
            # MARKER-------------------------------
            for j in range(len(output[i])):
                if output[i][j] > maxi:
                    maxi = output[i][j]
                    maxIndex = j
                output[i][j] = 0
            if Y[i][maxIndex] == 1:
                count += 1
        return count / self.m

    # activation function (sigmoid) that can also calculate g'(z) when flag is set
    @staticmethod
    def activate(layer, flag=False):
        if flag:
            return layer * (1 - layer)
        return 1 / (1 + np.exp(-layer))

    # function to remove delta corresponding to the bias units during back propagation
    @staticmethod
    def removeRedundantDelta(delta):
        newDelta = np.zeros((len(delta), len(delta[0]) - 1))
        for i in range(len(delta)):
            newDelta[i] = delta[i][:-1].copy()
        return newDelta

    # function to add bias units during forward propagation
    @staticmethod
    def addBias(layer):
        newLayer = np.zeros((len(layer), len(layer[0]) + 1))
        for i in range(len(layer)):
            newLayer[i] = np.append(layer[i], [1])
        return newLayer

# %%
def makeDict(arr):
    myDict = {}
    counter = 0
    for i in range(len(arr)):
        if not arr[i][0] in myDict.values():
            myDict[counter] = arr[i][0]
            counter += 1
    return myDict

# %%
def convertToOneHot(y, myDict):
    oneHot = np.zeros((len(y), len(myDict)))
    for i in range(len(y)):
        myKey = None
        for key, value in myDict.items():
            if value == y[i][0]:
                myKey = key
        oneHot[i][myKey] = 1
    return oneHot

# %%
def printBoundary(nn, xStart, xEnd, yStart, yEnd, xi, yi, noOfClasses):
    arr = []
    x1 = xStart
    while x1 <= xEnd:
        x2 = yStart
        while x2 <= yEnd:
            arr.append([x1, x2])
            x2 += xi
        x1 += yi
    
    nn.feedForward(np.array(arr))
    
    colourDict = {0:'r', 1:'b', 2:'y', 3:'k'}
    
    R = np.array([[0, 0], [0, 0]])
    Y = np.array([[0, 0], [0, 0]])
    B = np.array([[0, 0], [0, 0]])
    K = np.array([[0, 0], [0, 0]])
    for i in range(len(nn.layer[len(nn.layerN) - 1])):
        classIndex = np.argmax(nn.layer[len(nn.layerN) - 1][i])
        eg = [nn.layer[0][i][0], nn.layer[0][i][1]]
        if classIndex == 0:
            R = np.vstack((R, eg))
        elif classIndex == 1:
            B = np.vstack((B, eg))
        elif classIndex == 2:
            Y = np.vstack((Y, eg))
        elif classIndex == 3:
            K = np.vstack((K, eg))
    plt.plot(R[:,0], R[:,1], 'rs')
    plt.plot(B[:,0], B[:,1], 'bs')
    if len(Y) > 0:
        plt.plot(Y[:,0], Y[:,1], 'ys')
    if len(K) > 0:
        plt.plot(K[:,0], K[:,1], 'ks')
    plt.show()

# %%
def run(path, architecture, epochs, batchSize, delimiter=','):
    # Data Processing
    data = np.genfromtxt(path + '.txt', delimiter=delimiter)

    # input data
    x = np.array([[data[i][j] for j in range(2)] for i in range(len(data))])  # np.array(data[:,:2])
    # output data
    y = np.array([[data[i][2]] for i in range(len(data))])
    myDict = makeDict(y)
    yOneHot = convertToOneHot(y, myDict)

    # Model creation and training
    n = NeuralNetwork(architecture)
    print('Training now!')
    start = time.time()
    n.train(x, yOneHot, epochs=epochs, batchSize=batchSize)
    end = time.time()
    print('Training finished!')
    print('Time taken: ', end - start, 's')

    # Logging details
    n.feedForward(x)
    print('Accuracy: ', n.getAccuracy(x, yOneHot) * 100)
    
    image = io.imread(path + '.jpg')
    io.imshow(image)
    io.show()
    
    noOfClasses = len(myDict) # achitecture[len(architecture) - 1]
    indicesOfMax = np.argmax(x,axis = 0)
    x1Max = x[indicesOfMax[0]][0]
    x2Max = x[indicesOfMax[1]][1]
    indicesOfMin = np.argmin(x,axis = 0)
    x1Min = x[indicesOfMin[0]][0]
    x2Min = x[indicesOfMin[1]][1]
    printBoundary(n, x1Min - 1, x1Max + 1, x2Min - 1, x2Max + 1, 0.2, 0.2, noOfClasses)

# %%
run('NNClassificationData/clusterincluster', [2, 6, 6, 2], 200, 100, delimiter=' ')
# Out:
# Training now!
# Training finished!
# Time taken:  42.7995023727417 s
# Accuracy:  100.0

# %%
run('NNClassificationData/Corners', [2, 6, 6, 4], 200, 100, delimiter=' ')
# Out:
# Training now!
# Training finished!
# Time taken:  8.575740575790405 s
# Accuracy:  100.0

# %%
run('NNClassificationData/DoubleMoon1', [2, 6, 6, 2], 200, 100)
# Out:
# Training now!
# Training finished!
# Time taken:  88.91572284698486 s
# Accuracy:  100.0

# %%
run('NNClassificationData/DoubleMoon2', [2, 6, 6, 2], 200, 100)
# Out:
# Training now!
# Training finished!
# Time taken:  89.52527117729187 s
# Accuracy:  100.0

# %%
run('NNClassificationData/Half_kernel', [2, 6, 6, 2], 300, 100)
# Out:
# Training now!
# Training finished!
# Time taken:  14.515066623687744 s
# Accuracy:  100.0

# %%
run('NNClassificationData/Image1', [2, 6, 6, 2], 200, 100)
# Out:
# Training now!
# Training finished!
# Time taken:  86.1554114818573 s
# Accuracy:  100.0

# %%
run('NNClassificationData/Image2', [2, 6, 6, 2], 200, 100)
# Out:
# Training now!
# Training finished!
# Time taken:  86.47921061515808 s
# Accuracy:  100.0

# %%
run('NNClassificationData/Image3', [2, 6, 6, 2], 300, 100)
# Out:
# Training now!
# Training finished!
# Time taken:  127.52257966995239 s
# Accuracy:  99.99

# %%
run('NNClassificationData/Moon', [2, 6, 6, 2], 200, 100)
# Out:
# Training now!
# Training finished!
# Time taken:  8.447138547897339 s
# Accuracy:  100.0

# %%
run('NNClassificationData/Outlier', [2, 6, 6, 4], 200, 100)
# Out:
# Training now!
# Training finished!
# Time taken:  5.205784320831299 s
# Accuracy:  100.0
